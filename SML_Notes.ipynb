# %% [markdown]
# ***Statistical Machine Learning (SML)***

# %% [markdown]
# ***Machine Learning***
#
# The science of getting computers to act without being explicitly programmed.
#
#
# ***Goals of Machine Learning***
#
# -> To develop efficient **general** purpose prediction rules.
#
# -> To develop prediction rules that are as **accurate** as possible.
#
# -> To find prediction rules that could be **understood** by humans.
#
# ***Dataset***
#
# The collection of data on which a computer acts & implements/generate a Machine Learning Model.
#
# Eg: Iris-Dataset
#
# (Classification of Varieties on various parameters such as Petal length, Petal width, Sepal length, Sepal width, color, fragrance, amount of precipitation, geographical location, gynoecium, etc.)
#
# ![0*2c7voFri9cIXGrc4.jpeg](data:image/jpeg;base64,...)
#
# ![Screenshot 2023-01-19 at 10.29.21 AM.png](data:image/png;base64,...)

# %% [markdown]
# ***Workflow (T3 - Training, Tuning, Testing)***
#
# *Training* --> *Tuning* --> *Testing*
#
# 1. **Training**: To *set model parameters*
# 2. **Validation/Tuning**: To *set the Hyper-parameters*
# 3. **Testing**: To *compute the accuracy* of the model
#
# ![1*HEe_oHZHToY8oD1RoShHGg.png](data:image/png;base64,...)

# %% [markdown]
# Different types of ML Models:
#
# 1. kNN (k Nearest Neighbours)
# 2. k-fold Cross Validation
# 3. Leave one out Validation
# 4. Linear Regression Model
# 5. Logistic Regression Model

# %% [markdown]
# ***kNN Model***
#
# -> KNN algorithm applies the birds of a feather. It assumes that similar things are near to each other; that is, they are nearby.
#
# -> KNN captures some mathematics you learned as a child as you were trying to grasp the calculation of the distance between points on a graph. The idea of similarity (sometimes called closeness, proximity, or distance).
#
# => Euclidean distance or straight-line distance is a popular and familiar choice of calculating distance.
#
#
# ***How does KNN works?***
#
# The k-nearest neighbor algorithm stores all the available data and classifies a new data point based on the similarity measure (e.g., distance functions). This means when new data appears. Then it can be easily classified into a well-suited category by using K- NN algorithm.
#
# Suppose there are two classes, i.e., Class A and Class B, and we have a new unknown data point “$”, so this data point will lie in which of these classes. To solve this problem, we need a K-NN algorithm. With the help of K-NN, we can easily identify the class of a particular dataset. The data point is classified by a majority vote of its neighbors, with the data point being assigned to the class most common amongst its K nearest neighbors measured by a distance function.
#
# ***Choosing the right value for K***
#
# -> As K approaches 1, your prediction becomes less stable.
#
# -> As your value of K increases, your prediction becomes more stable due to the majority of voters.
#
# -> When you start receiving an increasing number of errors, you should know you are pushing your K too far.
#
# -> Taking a majority vote among labels needs K to be an odd number to have a tiebreaker.
#
# ![1rggfyd3.K-Nearest_Neighbors_pic2.png](data:image/png;base64,...)

# %% [markdown]
# ***k-fold Cross Validation Model***
#
# K-Fold CV is where a given data set is split into a K number of sections/folds where each fold is used as a testing set at some point. Lets take the scenario of 5-Fold cross validation(K=5). Here, the data set is split into 5 folds. In the first iteration, the first fold is used to test the model and the rest are used to train the model. In the second iteration, 2nd fold is used as the testing set while the rest serve as the training set. This process is repeated until each fold of the 5 folds have been used as the testing set.
#
# ![Screenshot 2023-01-19 at 10.05.50 AM.png](data:image/png;base64,...)

# %% [markdown]
# ***Leave One out Validation***
#
# LOOCV(Leave One Out Cross-Validation) is a type of cross-validation approach in which each observation is considered as the validation set and the rest (N-1) observations are considered as the training set.
#
# In LOOCV, fitting of the model is done and predicting using one observation validation set. Furthermore, repeating this for N times for each observation as the validation set. Model is fitted and the model is used to predict a value for observation.
#
# ![0*oHrfoOeToTpdkmHX.png](data:image/png;base64,...)

# %% [markdown]
# ***Linear Regression***
#
# Linear Regression is a machine learning algorithm based on *supervised* learning. It performs a regression task. Regression models a target prediction value based on independent variables. It is mostly used for finding out the relationship between variables and forecasting.
#
# Regression models differ based on – the kind of relationship between dependent and independent variables they are considering, and the number of independent variables getting used.
#
# Linear regression performs the task to predict a dependent variable value (y) based on a given independent variable (x)). Hence it's name!
#
# Eg: In finance, linear regression might be used to understand the relationship between a company’s stock price and its earnings, or to predict the future value of a currency based on its past performance.
#
# In the figure given below, **X** is the *Independent variable* & **Y** is the *Dependent variable*.
#
# ![Linear-Regression.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ***Logistic Regression***
#
# Logistic regression is a *supervised classification algorithm*.
#
# In a classification problem, the target variable 'y', can only take discrete values for a given set of input(s), X.
#
# The model builds a regression model to predict the probability that a given data entry belongs to the category numbered as “1”. Just like Linear regression assumes that the data follows a linear function, Logistic regression models the data using the sigmoid function.
#
# Logistic regression becomes a classification technique only when a decision threshold is brought into the picture. The setting of the threshold value is a very important aspect of Logistic regression and is dependent on the classification problem itself.
#
# ![46-4.png](data:image/png;base64,...)

# %% [markdown]
# ***Decision Boundaries***
#
# A Decision Boundary is a line (in the case of two features), where all (or most) samples of one class are on one side of that line, and all samples of the other class are on the opposite side of the line. The line separates one class from the other.
#
# If you have more than two features, the decision boundary is not a line, but a (hyper)-plane in the dimension of your feature space.
#
# **IMPORTANCE OF DECISION BOUNDARY**
#
# A Decision Boundary, is a surface that separates data points belonging to different class lables. Decision Boundaries are not only confined to just the data points that we have provided, but also they span through the entire feature space we trained on.
#
# The model can predict a value for any possible combination of inputs in our feature space.
#
# ![1*cgexp8r2e2RqfYqAh-oNfw.png](data:image/png;base64,...)

# %% [markdown]
# ***Tuning of a ML Model***
#
# *What is Model Tuning?*
#
# Model tuning is the experimental process of finding the optimal values of hyperparameters to maximize model performance. *Hyperparameters* are the set of variables whose values cannot be estimated by the model from the training data. These values control the training process. Model tuning is also known as ***Hyperparameter Optimization***.
#
# *Why is it Essential to Tune an ML Model?*
#
# The purpose of tuning a model is to ensure that it performs at its best. This process involves adjusting various elements of the model to achieve optimal results. By fine-tuning the model, you can maximize its performance and get the highest rate of performance possible.
#
# ***Types of Model Tuning Approaches***
#
# 1.*Manual tuning of Hyperparameters*
#
# 2.*Automated tuning of Hyperparameters*
#
# ![Screenshot 2023-01-24 at 10.06.54 AM.png](data:image/png;base64,...)
#
# **Manual Tuning of Hyperparameters**
#
# In manual tuning the values of the algorithms hyperparameters are determined by experience or intuition. The results of one training epoch are used to guess hyperparameters for the next training epoch.
#
# **Automated Tuning of Hyperparameters**
#
# In automated hyperparameter tuning, or optimization, multiple training jobs are submitted with different hyperparameter values. The hyperparameter values are chosen from a range set by the user. After each job completes the trained Model it is tested using validation data and a specified target variable. Target variables are also known as hyperparameter metrics.
#
# ***Types of Automated Tuning of Hyperparameters***
#
# 1. Grid Search
# 2. Random Search
# 3. Bayesian Search
#
# ![1*neqSOU-YOMg8m7HUClU-zg.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# A. **GRID SEARCH**
#
# A two dimensional table, or grid, of hyperparameter values is used to provide hyperparameter values that are eventually tested. Since, the method involves iterating over the whole set of possibilities in an exhausitive manner, this method is resource intensive as well as inefficient.
#
# ![learning_resources_03-05.png](data:image/png;base64,...)

# %% [markdown]
# B. **Random Search**
#
# This method is similar to Grid search however the hyperparameter pairs are chosen randomly.
# The Search for the hyperparameter is terminated by putting a cap on the resource limit or the time of execution of the search.
#
# ![gridrandom.png](data:image/png;base64,...)

# %% [markdown]
# C. **Bayesian Search**
#
# This method is a search guided by a statistical process to find optimum values for hyperparameters as quickly as possible. The Bayesian Search treats the choice of hyperparameter values as a linear regression problem. The results of previous training jobs are used to improve the selection of the next set of hyperparameters. Sometimes the new hyperparameters are close to the previous ones to find subtle improvements, other times the values chosen are distant to search the range of values.
#
# ![WordPress-Featured-Images.png.webp](data:image/webp;base64,...)

# %% [markdown]
# ***Some other Tuning Methods***
#
# **Evolutionary Search**
#
# An EA(Evolutionary Algorithm) contains four overall steps: initialization, selection, genetic operators, and termination. These steps each correspond, roughly, to a particular facet of natural selection, and provide easy ways to modularize implementations of this algorithm category.
#
# In Layman terms, in an EA, fitter members will survive and proliferate, while unfit members will die off and not contribute to the gene pool of further generations, much like in natural selection.
#
# ![image2.png](data:image/png;base64,...)
#
# **Gradient Search**
#
# Gradient descent (GD) is an iterative first-order optimisation algorithm used to find a local minimum/maximum of a given function. This method is commonly used in machine learning (ML) and deep learning(DL) to minimise a cost/loss function (e.g. in a linear regression).
#
# ![akira-ai-gradient-descent-algorithm.webp](data:image/webp;base64,...)
